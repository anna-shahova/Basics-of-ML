# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons, make_circles

# %%
X1, y1 = make_moons(n_samples=200, noise=0.01, random_state=0)
 
plt.scatter(X1[:, 0], X1[:, 1], c=y1)
plt.show()

# %%
from sklearn.model_selection import train_test_split
X1_train, X1_test, y1_train, y1_test = train_test_split(X1,y1, test_size=0.2, train_size=0.8, random_state = 0)
print(f'X_train shape: {X1_train.shape}',
      f'X_test shape: {X1_test.shape}',
      f'y_train shape: {y1_train.shape}',
      f'y_test shape: {y1_test.shape}')
# Out:
# X_train shape: (160, 2) X_test shape: (40, 2) y_train shape: (160,) y_test shape: (40,)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

k_values = range(1, 9)
accuracy_scores = []

for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X1_train, y1_train)
    y1_pred = knn.predict(X1_test)
    accuracy = accuracy_score(y1_test, y1_pred)
    accuracy_scores.append(accuracy)

plt.plot(k_values, accuracy_scores)
plt.xlabel('k')
plt.ylabel('Accuracy')
plt.title('Classification Accuracy of KNN Model')
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
accuracy = accuracy_score(y1_test, y1_pred)
precision = precision_score(y1_test, y1_pred)
recall = recall_score(y1_test, y1_pred)
f1 = f1_score(y1_test, y1_pred)
print(f'Accuracy: {accuracy}, Precision: {precision}, Recall: {recall}, F1: {f1}')
# Out:
# Accuracy: 1.0, Precision: 1.0, Recall: 1.0, F1: 1.0

# %%
from sklearn.metrics import confusion_matrix
matrix = confusion_matrix(y1_test, y1_pred)
print(matrix)
# Out:
# [[22  0]
#  [ 0 18]]

# %%
X2, y2 = make_circles(n_samples=200, factor=0.5, noise=0.1, shuffle=True, random_state=42)
plt.scatter(X2[:, 0], X2[:, 1], c=y2, cmap='viridis')
plt.show()

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.2, train_size=0.8, random_state = 0)
print(f'X_train shape: {X2_train.shape}',
      f'X_test shape: {X2_test.shape}',
      f'y_train shape: {y2_train.shape}',
      f'y_test shape: {y2_test.shape}')
# Out:
# X_train shape: (160, 2) X_test shape: (40, 2) y_train shape: (160,) y_test shape: (40,)

# %%
k_values = range(1, 9)
accuracy_scores = []

for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X2_train, y2_train)
    y2_pred = knn.predict(X2_test)
    accuracy = accuracy_score(y2_test, y2_pred)
    accuracy_scores.append(accuracy)

plt.plot(k_values, accuracy_scores)
plt.xlabel('k')
plt.ylabel('Accuracy')
plt.title('Classification Accuracy of KNN Model')
plt.show()

# %%
accuracy = accuracy_score(y2_test, y2_pred)
precision = precision_score(y2_test, y2_pred)
recall = recall_score(y2_test, y2_pred)
F1 = f1_score(y2_test, y2_pred)
print(f'Accuracy: {accuracy}, Precision: {precision}, Recall: {recall}, F1: {F1}')
# Out:
# Accuracy: 0.975, Precision: 0.95, Recall: 1.0, F1: 0.9743589743589743

# %%
matrix = confusion_matrix(y2_test, y2_pred)
print(matrix)
# Out:
# [[20  1]
#  [ 0 19]]

# %%
x = np.random.uniform(-10, 10, 200)
y = np.random.uniform(-10, 10, 200)
class1 = (x < 0) & (y < 0) | (x > 0) & (y > 0)
class2 = (x < 0) & (y > 0) | (x > 0) & (y < 0)
dataset = np.array([x, y, class1, class2]).T
plt.scatter(x, y, c=class1, s=50, alpha=0.5)
plt.scatter(x, y, c=class2, s=50, alpha=0.5)
plt.show()

# %%
train_set, test_set = train_test_split(dataset, test_size=0.2, train_size=0.8, random_state = 0)
print(f'train_set shape: {train_set.shape}',
      f'test_set: {test_set.shape}')
# Out:
# train_set shape: (160, 4) test_set: (40, 4)

# %%
k_values = range(1, 9)
accuracy_scores = []

for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(train_set[:, :2], train_set[:, 2])
    y4_pred = knn.predict(test_set[:, :2])
    accuracy = accuracy_score(test_set[:, 2], y4_pred)
    accuracy_scores.append(accuracy)

plt.plot(k_values, accuracy_scores)
plt.xlabel('k')
plt.ylabel('Accuracy')
plt.title('Classification Accuracy of KNN Model')
plt.show()

# %%
accuracy = accuracy_score(test_set[:, 2], y4_pred)
precision = precision_score(test_set[:, 2], y4_pred)
recall = recall_score(test_set[:, 2], y4_pred)
F1 = f1_score(test_set[:, 2], y4_pred)
print(f'Accuracy: {accuracy}, Precision: {precision}, Recall: {recall}, F1: {F1}')
# Out:
# Accuracy: 0.975, Precision: 1.0, Recall: 0.9565217391304348, F1: 0.9777777777777777

# %%
matrix = confusion_matrix(test_set[:, 2], y4_pred)
print(matrix)
# Out:
# [[17  0]
#  [ 1 22]]
